# %%
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
df = pd.read_csv("./log.csv");
# df = df[ df.publish != '-' ]
df.sample()
# Out:
#                     id publish                       receive  connections
# 1133903  17d3f28e-6212       -  2019-10-14T13:06:29.255+0200          741

# %%
plt.figure(figsize=(15, 5));
plt.plot(df.id, df.connections, 'o-', label='connections');
plt.legend();

# %%
def format(data):
    return data[:19]
plt.figure(figsize=(15, 5));
plt.plot( [format(v) for _,v in enumerate(df.publish)], df.id, 'o-', label='publish');
plt.plot( [format(v) for _,v in enumerate(df.receive)], df.id, 'o-', label='receive');
plt.legend();
